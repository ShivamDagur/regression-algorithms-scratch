# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivamDagur/regression-algorithms-scratch/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %% [markdown]
# ***1 . SOME STATISTICS FUNCTIONS***

# %%
# 1.a : Mean...
def mean(data) :
  return sum(data)/len(data)

# 1.b : Variance...
def variance(data):
  m = mean(data)
  return sum([(x-m)**2 for x in data])/len(data)

# 1.c : Standard Deviation...
def std(data):
  return math.sqrt(variance(data))

# 1.d : Covariance...
def covariance(data1,data2):
  res = 0
  m1 = mean(data1)
  m2 = mean(data2)
  for i in range(len(data1)):
    res += (data1[i]-m1)*(data2[i]-m2)
  return res/(len(data1)-1)

# 1.e : Correlation...
def correlation(data1,data2):
  return covariance(data1,data2)/std(data1)/std(data2)

# %% [markdown]
# ***2. SLOPE (m) AND INTERCEPT (c) — Least Squares Method --***
